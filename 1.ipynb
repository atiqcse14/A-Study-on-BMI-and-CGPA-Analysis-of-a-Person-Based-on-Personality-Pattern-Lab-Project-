# %%
import pandas as pd
data_xls = pd.read_excel('Dataset_New.xlsx', index_col=None)
data_xls.to_csv('Dataset_New.csv', encoding='utf-8',index=False)

# %%
first = pd.read_csv('Dataset_New.csv')
first.head()
# Out:
#              Timestamp  Score           ID  Gender  Height  Weight   CGPA  \
# 0  2019-03-27 12:37:00  0 / 1  151340905.0  Female  158.50    58.0  3.930
# 1  2019-03-29 01:19:00  0 / 1  151341043.0    Male  176.78    70.0  3.845
# 2  2019-03-27 12:52:00  0 / 1  151340925.0    Male  164.59    60.0  3.830
# 3  2019-03-27 12:45:00  0 / 1  151340912.0    Male  178.31    68.0  3.800
# 4  2019-03-27 12:39:00  0 / 1  151340898.0  Female  167.64    60.0  3.770
#
#   Daily spent time in social media (hour)    Hometown  \
# 0                     2019-05-02 00:00:00     Comilla
# 1                     2019-05-02 00:00:00  Munshiganj
# 2                            Below 1 hour     Barisal
# 3                     2019-05-02 00:00:00     Barisal
# 4                     2019-05-02 00:00:00       Dhaka
#
#   How many days in a week you feel more energetic       ...        \
# 0                             2019-02-01 00:00:00       ...
# 1                                               2       ...
# ...

# %%
column_name = [
    'ID', 'Height' , 'Weight'
]
df = first[column_name]
df
# Out:
#               ID    Height  Weight
# 0    151340905.0  158.5000    58.0
# 1    151341043.0  176.7800    70.0
# 2    151340925.0  164.5900    60.0
# 3    151340912.0  178.3100    68.0
# 4    151340898.0  167.6400    60.0
# 5    151341027.0  182.5752    70.0
# 6    151341011.0  161.5440    59.0
# 7    151341004.0  170.6880    70.0
# 8    151341000.0  158.4960    52.0
# 9    151340923.0  167.6400    67.0
# 10   151340944.0  179.8320    62.0
# 11   151340928.0  185.9280    65.0
# 12   151341009.0  164.5920    49.0
# 13   151340910.0  182.5752   110.0
# 14   141440899.0  156.0000    76.0
# 15   151341035.0  167.6400    50.0
# 16   151340909.0  179.8320    74.0
# 17   151340939.0  161.5440    47.0
# 18   151340897.0  182.8800    85.0
# 19   151340988.0  161.5440    54.0
# 20   151340942.0  164.5920    54.0
# 21   151340931.0  182.5752    60.0
# 22   151340984.0  170.6880    75.0
# 23   151340982.0  164.5920    60.0
# 24   151341021.0  161.5440    61.0
# 25   151340927.0  161.5440    45.0
# ...

# %%
res = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-070c493eb458> in <module>()
# ----> 1 res = df.dropna()
#
# NameError: name 'df' is not defined

# %%
res

# %%
column_name = [
    'ID', 'Height' , 'Weight'
]
df2 = first[column_name]
df2 = df2.dropna()
df2
# Out:
#               ID    Height  Weight
# 0    151340905.0  158.5000    58.0
# 1    151341043.0  176.7800    70.0
# 2    151340925.0  164.5900    60.0
# 3    151340912.0  178.3100    68.0
# 4    151340898.0  167.6400    60.0
# 5    151341027.0  182.5752    70.0
# 6    151341011.0  161.5440    59.0
# 7    151341004.0  170.6880    70.0
# 8    151341000.0  158.4960    52.0
# 9    151340923.0  167.6400    67.0
# 10   151340944.0  179.8320    62.0
# 11   151340928.0  185.9280    65.0
# 12   151341009.0  164.5920    49.0
# 13   151340910.0  182.5752   110.0
# 14   141440899.0  156.0000    76.0
# 15   151341035.0  167.6400    50.0
# 16   151340909.0  179.8320    74.0
# 17   151340939.0  161.5440    47.0
# 18   151340897.0  182.8800    85.0
# 19   151340988.0  161.5440    54.0
# 20   151340942.0  164.5920    54.0
# 21   151340931.0  182.5752    60.0
# 22   151340984.0  170.6880    75.0
# 23   151340982.0  164.5920    60.0
# 24   151341021.0  161.5440    61.0
# 25   151340927.0  161.5440    45.0
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df2['Height'], df2['Weight'])
plt.show()

# %%
boxplot = df2.boxplot(column=['Height','Weight'], return_type='axes')

# %%
df2['Height'] = df2 ['Height']/100

# %%
df2['Height2'] = df2['Height'] * df2['Height']
df2['Height2']
# Out:
# 0      2.512225
# 1      3.125117
# 2      2.708987
# 3      3.179446
# 4      2.810317
# 5      3.333370
# 6      2.609646
# 7      2.913439
# 8      2.512098
# 9      2.810317
# 10     3.233955
# 11     3.456922
# 12     2.709053
# 13     3.333370
# 14     2.433600
# 15     2.810317
# 16     3.233955
# 17     2.609646
# 18     3.344509
# 19     2.609646
# 20     2.709053
# 21     3.333370
# 22     2.913439
# 23     2.709053
# 24     2.609646
# 25     2.609646
# 26     2.810317
# 27     3.333370
# 28     2.913439
# 29     2.425893
#          ...
# 73     2.512098
# 74     1.561700
# 75     2.913439
# 76     2.913439
# 77     3.125258
# 78     3.018420
# 79     2.709053
# 80     2.609646
# 81     3.125258
# 82     2.421148
# 83     2.609646
# 84     2.913439
# 85     3.344509
# 86     2.709053
# 87     3.125258
# 88     2.913439
# 89     3.125258
# 90     2.322576
# 91     2.810317
# 92     2.810317
# 93     3.125258
# 94     3.333370
# 95     2.608225
# 96     3.294225
# ...

# %%
df2['BMI'] = df2['Weight'] / (df2['Height'] * df2['Height'])

# %%
df2['BMI']
# Out:
# 0      23.087104
# 1      22.399163
# 2      22.148502
# 3      21.387376
# 4      21.349905
# 5      20.999767
# 6      22.608427
# 7      24.026586
# 8      20.699828
# 9      23.840727
# 10     19.171573
# 11     18.802853
# 12     18.087504
# 13     32.999633
# 14     31.229454
# 15     17.791587
# 16     22.882200
# 17     18.010103
# 18     25.414788
# 19     20.692459
# 20     19.933167
# 21     17.999800
# 22     25.742770
# 23     22.147964
# 24     23.374814
# 25     17.243716
# 26     21.705737
# 27     15.899823
# 28     22.996875
# 29     32.977540
#          ...
# 73     22.690196
# 74     32.656718
# 75     16.475373
# 76     15.788899
# 77     20.798281
# 78     16.564959
# 79     22.147964
# 80     23.758008
# 81     24.957937
# 82     29.737954
# 83     28.739526
# 84     23.340112
# 85     21.826818
# 86     22.147964
# 87     26.237832
# 88     21.280690
# 89     28.797620
# 90     15.930587
# 91     22.773232
# 92     29.178203
# 93     23.678043
# ...

# %%
column_name = [
    'ID', 'Height' , 'Weight' , 'BMI'
]
df3 = df2[column_name]

# %%
import numpy as np

conditions = [
    (df3['BMI'] <= 18.5),
    (df3['BMI'] >= 18.5) & (df3['BMI'] <= 24.9),
    (df3['BMI'] >= 25) & (df3['BMI'] <= 29.9)]
choices = ['Underweight', 'Normal', 'Overweight']
df3['Physical_Condition'] = np.select(conditions, choices, default='Obese')

# %%
df3 = df3.dropna()
df3
# Out:
#               ID    Height  Weight        BMI Physical_Condition
# 0    151340905.0  1.585000    58.0  23.087104             Normal
# 1    151341043.0  1.767800    70.0  22.399163             Normal
# 2    151340925.0  1.645900    60.0  22.148502             Normal
# 3    151340912.0  1.783100    68.0  21.387376             Normal
# 4    151340898.0  1.676400    60.0  21.349905             Normal
# 5    151341027.0  1.825752    70.0  20.999767             Normal
# 6    151341011.0  1.615440    59.0  22.608427             Normal
# 7    151341004.0  1.706880    70.0  24.026586             Normal
# 8    151341000.0  1.584960    52.0  20.699828             Normal
# 9    151340923.0  1.676400    67.0  23.840727             Normal
# 10   151340944.0  1.798320    62.0  19.171573             Normal
# 11   151340928.0  1.859280    65.0  18.802853             Normal
# 12   151341009.0  1.645920    49.0  18.087504        Underweight
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df3['ID'], df3['BMI'])
plt.show()

# %%
df3.plot.box()

# %%
df3['BMI'].hist()

# %%
df3.hist()
plt.show()

# %%
pd.scatter_matrix(df3, diagonal = 'kde')
plt.show()
# Out:
# D:\InstalledSoftware\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
column_name = [
    'ID' , 'CGPA' , 'Theory class attendance(h,l,m)' , 'Preference(class lectures cl or online tutorials)'
]
df4 = first[column_name]
df4 = df4.dropna()
df4
# Out:
#              ID   CGPA Theory class attendance(h,l,m)  \
# 0   151340905.0  3.930                              h
# 1   151341043.0  3.845                           High
# 2   151340925.0  3.830                              h
# 3   151340912.0  3.800                              h
# 4   151340898.0  3.770                              m
# 5   151341027.0  3.760                              h
# 6   151341011.0  3.720                              h
# 7   151341004.0  3.710                              h
# 8   151341000.0  3.690                              h
# 9   151340923.0  3.680                              h
# 10  151340944.0  3.640                              h
# 11  151340928.0  3.640                              h
# 12  151341009.0  3.640                              h
# 13  151340910.0  3.620                              h
# 14  141440899.0  3.620                              h
# 15  151341035.0  3.620                              h
# ...

# %%
df04=df4.stack().str.replace('h','H').unstack()

# %%
df004=df04.stack().str.replace('High','H').unstack()

# %%
df0004=df004.stack().str.replace('m','M').unstack()

# %%
df00004=df0004.stack().str.replace('medium','M').unstack()

# %%
df5=df00004.stack().str.replace('MediuM','M').unstack()

# %%
df05=df5.stack().str.replace('HigH','H').unstack()

# %%
df005=df05.stack().str.replace('1','H').unstack()

# %%
df6=df005.stack().str.replace('0.9','H').unstack()

# %%
df6=df6.stack().str.replace('H.','H').unstack()

# %%
df6
# Out:
#    Theory class attendance(h,l,m)  \
# 0                               H
# 1                               H
# 2                               H
# 3                               H
# 4                               M
# 5                               H
# 6                               H
# 7                               H
# 8                               H
# 9                               H
# 10                              H
# 11                              H
# 12                              H
# 13                              H
# 14                              H
# 15                              H
# 16                              M
# 17                              M
# 18                              H
# 19                              l
# 20                              H
# 21                              H
# 22                              M
# 23                              H
# 24                              H
# 25                              H
# ...

# %%
df4['Theory class attendance(h,l,m)'] = df6['Theory class attendance(h,l,m)']

# %%
plt.scatter(df4['CGPA'], df4['Theory class attendance(h,l,m)'])
plt.show()

# %%
df4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DB1C39BD68>,
# ...
#       dtype=object)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
D=df3.values


# Get the labelled set
c1=D[:20,:]; c2=D[51:80,:];  c3=D[91:100,:]
trainSet = np.concatenate((c1,c2,c3),axis=0)

# Get the testing set
c1 = D[21:50,:]; c2=D[81:90,:];  c3=D[100:,:]
testSet = np.concatenate((c1,c2,c3),axis=0)

print(trainSet.shape)
print(testSet.shape)

xTrain=trainSet[:,:-1]; yTrain=trainSet[:,-1]
xTest=testSet[:,:-1]; yTest=testSet[:,-1]

print(yTest)
# Out:
# (58, 5)
# (41, 5)
# ['Underweight' 'Overweight' 'Normal' 'Normal' 'Underweight' 'Normal'
#  'Underweight' 'Normal' 'Obese' 'Normal' 'Normal' 'Obese' 'Underweight'
#  'Normal' 'Underweight' 'Underweight' 'Normal' 'Overweight' 'Normal'
#  'Underweight' 'Normal' 'Underweight' 'Overweight' 'Normal' 'Normal'
#  'Normal' 'Normal' 'Overweight' 'Normal' 'Obese' 'Overweight' 'Overweight'
#  'Normal' 'Normal' 'Normal' 'Overweight' 'Normal' 'Overweight' 'Normal'
#  'Normal' 'Normal']

# %%
# create a knn classifier with K=3
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(xTrain, yTrain.astype(str))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
# Make predictions
yPred=clf.predict(xTest)
acc=accuracy_score(yTest.astype(str), yPred.astype(str))
print('Accuracy with 3 neighbours: ',acc)
# Out:
# Accuracy with 3 neighbours:  0.6585365853658537

# %%
def plot_conf_mat(lTrue, lPred, title):
    """ A function for plotting the confusion matrix given true and predicted labels."""
    cm = confusion_matrix(lTrue.astype(str), lPred.astype(str))
    print(cm)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
plot_conf_mat(yTest, yPred, 'K=3')
# Out:
# [[20  0  2  0]
#  [ 2  0  1  0]
#  [ 4  0  4  0]
#  [ 5  0  0  3]]

# %%
df3.head()
# Out:
#             ID  Height  Weight        BMI Physical_Condition
# 0  151340905.0  1.5850    58.0  23.087104             Normal
# 1  151341043.0  1.7678    70.0  22.399163             Normal
# 2  151340925.0  1.6459    60.0  22.148502             Normal
# 3  151340912.0  1.7831    68.0  21.387376             Normal
# 4  151340898.0  1.6764    60.0  21.349905             Normal

# %%
df3.head()
# Out:
#             ID  Height  Weight        BMI Physical_Condition
# 0  151340905.0  1.5850    58.0  23.087104             Normal
# 1  151341043.0  1.7678    70.0  22.399163             Normal
# 2  151340925.0  1.6459    60.0  22.148502             Normal
# 3  151340912.0  1.7831    68.0  21.387376             Normal
# 4  151340898.0  1.6764    60.0  21.349905             Normal

# %%
df7 = pd.concat([first, df3], axis =1, join = 'inner')

df7
# Out:
#                Timestamp  Score           ID  Gender    Height Weight   CGPA  \
# 0    2019-03-27 12:37:00  0 / 1  151340905.0  Female  158.5000   58.0  3.930
# 1    2019-03-29 01:19:00  0 / 1  151341043.0    Male  176.7800   70.0  3.845
# 2    2019-03-27 12:52:00  0 / 1  151340925.0    Male  164.5900   60.0  3.830
# 3    2019-03-27 12:45:00  0 / 1  151340912.0    Male  178.3100   68.0  3.800
# 4    2019-03-27 12:39:00  0 / 1  151340898.0  Female  167.6400   60.0  3.770
# 5    2019-03-24 14:46:00  0 / 1  151341027.0    Male  182.5752   70.0  3.760
# 6    2019-03-24 14:33:00  0 / 1  151341011.0    Male  161.5440   59.0  3.720
# 7    2019-03-24 14:41:00  0 / 1  151341004.0    Male  170.6880   70.0  3.710
# 8    2019-03-25 14:32:00  0 / 1  151341000.0  Female  158.4960   52.0  3.690
# 9    2019-03-27 13:05:00  0 / 1  151340923.0    Male  167.6400   67.0  3.680
# 10   2019-03-27 13:04:00  0 / 1  151340944.0    Male  179.8320   62.0  3.640
# ...

# %%
column_name = [
    'ID', 'BMI' , 'Physical_Condition' , 'Gender'
]
df7 = df7[column_name]
df7 = df7.dropna()
df7
# Out:
#               ID           ID        BMI Physical_Condition  Gender
# 0    151340905.0  151340905.0  23.087104             Normal  Female
# 1    151341043.0  151341043.0  22.399163             Normal    Male
# 2    151340925.0  151340925.0  22.148502             Normal    Male
# 3    151340912.0  151340912.0  21.387376             Normal    Male
# 4    151340898.0  151340898.0  21.349905             Normal  Female
# 5    151341027.0  151341027.0  20.999767             Normal    Male
# 6    151341011.0  151341011.0  22.608427             Normal    Male
# 7    151341004.0  151341004.0  24.026586             Normal    Male
# 8    151341000.0  151341000.0  20.699828             Normal  Female
# 9    151340923.0  151340923.0  23.840727             Normal    Male
# 10   151340944.0  151340944.0  19.171573             Normal    Male
# 11   151340928.0  151340928.0  18.802853             Normal    Male
# 12   151341009.0  151341009.0  18.087504        Underweight  Female
# ...

# %%
plt.scatter(df7['Physical_Condition'], df7['Gender'])
plt.show()

# %%
column_name = [
   'Physical_Condition' , 'Gender'
]
df7 = df7[column_name]
df7 = df7.dropna()
df7
# Out:
#     Physical_Condition  Gender
# 0               Normal  Female
# 1               Normal    Male
# 2               Normal    Male
# 3               Normal    Male
# 4               Normal  Female
# 5               Normal    Male
# 6               Normal    Male
# 7               Normal    Male
# 8               Normal  Female
# 9               Normal    Male
# 10              Normal    Male
# 11              Normal    Male
# 12         Underweight  Female
# 13               Obese    Male
# 14               Obese  Female
# 15         Underweight    Male
# 16              Normal  Female
# 17         Underweight  Female
# 18          Overweight    Male
# 19              Normal  Female
# 20              Normal  Female
# 21         Underweight    Male
# 22          Overweight    Male
# 23              Normal  Female
# 24              Normal    Male
# 25         Underweight  Female
# 26              Normal  Female
# 27         Underweight  Female
# 28              Normal  Female
# ...

# %%
import seaborn as sns
sns.countplot(x='Physical_Condition', data=df7, palette='viridis')

# %%
df7=df7.stack().str.replace('Male','1').unstack()

# %%
df7=df7.stack().str.replace('Female','0').unstack()

# %%
df7['Gender'] = df7['Gender'].astype(int)

# %%
count_a = 0;
count_b = 0;
for val in df7['Gender']:
    if(val==1):
        count_a = count_a+1;
    else:
        count_b = count_b+1;

# %%
labels = 'Male', 'Female'
sizes = [count_a, count_b]
explode = (0, 0.1) 

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
